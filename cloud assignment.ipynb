# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random

# %% [markdown]
# ## Standard AIMD

# %%
def AIMD(a1=1, a2=1, b1=0.5, b2=0.5, iters=100):
    ITERATESMAX = iters # You can adjust this value as needed
    C = 10 # Adjust C value as needed

    x1 = 8
    x2 = 1

    x1_values = np.zeros(ITERATESMAX)
    x2_values = np.zeros(ITERATESMAX)

    for i in range(ITERATESMAX):
        if (x1 + x2 <= C):
            # Additive increase phase
            print('Additive I')
            x1 = x1 + a1
            x2 = x2 + a2
        else:
            # Simulate network condition (for example, congestion)
            print('Multiplicative D')
            beta1 = b1
            beta2 = b2
            x1 = x1 * b1
            x2 = x2 * b2
        # Store values in arrays
        x1_values[i] = x1
        x2_values[i] = x2
    # Display the final values
    print("Final x1:", x1)
    print("Final x2:", x2)
    
    # calculate fairness vector
    fairness_vector = [a1/(1-b1), a2/(1-b2)]
    
    return x1_values, x2_values, fairness_vector

# %%
def plotAIMD(x1_values, x2_values, fairness_vector, title):
    # convert fairness vector into coordinates of line
    fairness_coords = [[0, x] for x in fairness_vector]
    # plot allocations of users
    plt.plot(x1_values, x2_values, '-o')
    # plot fairness line, scale line by 10 times to extend the vector
    plt.plot([x*10 for x in fairness_coords[0]], [x*10 for x in fairness_coords[1]],label='Fairness line')
    # plot maximum capacity line
    plt.plot([0,10],[10,0], label='Max Capacity')
    
    plt.legend()
    plt.title(title)
    plt.xlabel("User 1's allocation x1")
    plt.ylabel("User 2's allocation x2")
    plt.xlim([0, 12])
    plt.ylim([0, 12])

    plt.show()

# %%
x1_values, x2_values, fairness_vector = AIMD()
# Out:
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Final x1: 5.000000089406967
# Final x2: 4.9999998807907104

# %%
plotAIMD(x1_values, x2_values, fairness_vector,title="Standard AIMD")

# %%
x1_values, x2_values, fairness_vector = AIMD(2,3,0.3,0.5)
# Out:
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Final x1: 3.5127359483545018
# Final x2: 7.935483870967801

# %%
plotAIMD(x1_values, x2_values, fairness_vector, title="AIMD with adjusted a and b")

# %% [markdown]
# ## Non-linear Functions

# %% [markdown]
# ### Power AI

# %% [markdown]
# a(w) = w<sup>e</sup> <br>

# %%
def AI_pow(b1=0.5, b2=0.5, e1=0.5, e2=1, iters=100):
    ITERATESMAX = iters # You can adjust this value as needed
    C = 10 # Adjust C value as needed

    x1 = 8
    x2 = 1

    x1_values = np.zeros(ITERATESMAX)
    x2_values = np.zeros(ITERATESMAX)

    for i in range(ITERATESMAX):
        if (x1 + x2 <= C):
            # Additive increase phase
            print('Additive I')
            x1 = x1 + (x1**e1)
            x2 = x2 + (x2**e2)
        else:
            # Simulate network condition (for example, congestion)
            print('Multiplicative D')
            x1 = x1 * b1
            x2 = x2 * b2
        # Store values in arrays
        x1_values[i] = x1
        x2_values[i] = x2
    # Display the final values
    print("Final x1:", x1)
    print("Final x2:", x2)
    
    return x1_values, x2_values

# %%
def plotAIMD_nonlinear(x1_values, x2_values, title):
    # plot allocations of users
    plt.plot(x1_values, x2_values, '-o')
    # plot maximum capacity line
    plt.plot([0,10],[10,0], label='Max Capacity')
    
    plt.legend()
    plt.title(title)
    plt.xlabel("User 1's allocation x1")
    plt.ylabel("User 2's allocation x2")
    plt.xlim([0, 12])
    plt.ylim([0, 12])

    plt.show()

# %%
x1_values, x2_values = AI_pow()
# Out:
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Final x1: 1.000004303967645
# Final x2: 4.0

# %%
plotAIMD_nonlinear(x1_values, x2_values, title="AIMD x^c")

# %%
x1_values, x2_values = AI_pow(e1=0.1)
# Out:
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Final x1: 1.000000000001943
# Final x2: 4.0

# %%
plotAIMD_nonlinear(x1_values, x2_values, title="AIMD x^c")

# %%
x1_values, x2_values = AI_pow(e1=0.1, e2=0.1)
# Out:
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Final x1: 3.034166207329534
# Final x2: 3.034166081515724

# %%
plotAIMD_nonlinear(x1_values, x2_values, title="AIMD x^c")

# %% [markdown]
# ### Power AIMD

# %% [markdown]
# a(w) = w<sup>e</sup> <br>
# b(w) = (1/w<sup>e</sup>)

# %%
def AIMD_pow(e1=0.5, e2=1, iters=100):
    ITERATESMAX = iters # You can adjust this value as needed
    C = 10 # Adjust C value as needed

    x1 = 5
    x2 = 1

    x1_values = np.zeros(ITERATESMAX)
    x2_values = np.zeros(ITERATESMAX)

    for i in range(ITERATESMAX):
        if (x1 + x2 <= C):
            # Additive increase phase
            print('Additive I')
            x1 = x1 + x1**e1
            x2 = x2 + x2**e2
        else:
            # Simulate network condition (for example, congestion)
            print('Multiplicative D')
#             print('x1=',x1)
#             print('x1 * ', 1/(x1**e1))
            x1 = x1 * 1/(x1**e1)
            x2 = x2 * 1/(x2**e2)
        # Store values in arrays
        x1_values[i] = x1
        x2_values[i] = x2
    # Display the final values
    print("Final x1:", x1)
    print("Final x2:", x2)
    
    return x1_values, x2_values

# %%
x1_values, x2_values = AIMD_pow()
# Out:
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Final x1: 4.021954160571987
# Final x2: 2.0

# %%
plotAIMD_nonlinear(x1_values, x2_values, title="AIMD x^c")

# %%
x1_values, x2_values = AIMD_pow(e1=0.5, e2=0.5)
# Out:
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Final x1: 4.021954160571987
# Final x2: 4.021954160571985

# %%
plotAIMD_nonlinear(x1_values, x2_values, title="AIMD x^c")

# %%
x1_values, x2_values = AIMD_pow(e1=0.1, e2=0.1)
# Out:
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Final x1: 5.008918513463799
# Final x2: 5.008916148565926

# %%
plotAIMD_nonlinear(x1_values, x2_values, title="AIMD x^c")

# %% [markdown]
# ## Log AI

# %%
def AI_log(a1=1, a2=1, b1=0.5, b2=0.5, iters=100):
    ITERATESMAX = iters # You can adjust this value as needed
    C = 10 # Adjust C value as needed

    x1 = 5
    x2 = 1

    x1_values = np.zeros(ITERATESMAX)
    x2_values = np.zeros(ITERATESMAX)

    for i in range(ITERATESMAX):
        if (x1 + x2 <= C):
            # Additive increase phase
            print('Additive I')
            x1 = x1 + np.log(x1 + 1)
            x2 = x2 + np.log(x2 + 1)
        else:
            # Simulate network condition (for example, congestion)
            print('Multiplicative D')
            x1 = x1 * b1
            x2 = x2 * b2
        # Store values in arrays
        x1_values[i] = x1
        x2_values[i] = x2
    # Display the final values
    print("Final x1:", x1)
    print("Final x2:", x2)
    
    return x1_values, x2_values

# %%
x1_values, x2_values = AI_log()
# Out:
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Final x1: 4.552445875650424
# Final x2: 4.552222430353491

# %%
plotAIMD_nonlinear(x1_values, x2_values, title="AIMD log")

# %% [markdown]
# ## Log AIMD

# %%
def AIMD_log(a1=1, a2=1, b1=0.5, b2=0.5, iters=100):
    ITERATESMAX = iters # You can adjust this value as needed
    C = 10 # Adjust C value as needed

    x1 = 5
    x2 = 1

    x1_values = np.zeros(ITERATESMAX)
    x2_values = np.zeros(ITERATESMAX)

    for i in range(ITERATESMAX):
        if (x1 + x2 <= C):
            # Additive increase phase
            print('Additive I')
            x1 = x1 + np.log(x1 + 1)
            x2 = x2 + np.log(x2 + 1)
        else:
            # Simulate network condition (for example, congestion)
            print('Multiplicative D')
            x1 = x1 * 1/np.log(x2 + 1)
            x2 = x2 * 1/np.log(x2 + 1)
        # Store values in arrays
        x1_values[i] = x1
        x2_values[i] = x2
    # Display the final values
    print("Final x1:", x1)
    print("Final x2:", x2)
    
    return x1_values, x2_values

# %%
x1_values, x2_values = AIMD_log()
# Out:
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Final x1: 3.178758959291465
# Final x2: 3.17854344275472

# %%
plotAIMD_nonlinear(x1_values, x2_values, title="AIMD log")

# %% [markdown]
# ## AIMD Exponential

# %%
def AI_exp(a1=5, a2=5, b1=0.5, b2=0.5, e1=1.2, e2=1.2, iters=100):
    ITERATESMAX = iters # You can adjust this value as needed
    C = 10 # Adjust C value as needed

    x1 = 5
    x2 = 1

    x1_values = np.zeros(ITERATESMAX)
    x2_values = np.zeros(ITERATESMAX)

    for i in range(ITERATESMAX):
        if (x1 + x2 <= C):
            # Additive increase phase
            print('Additive I')
            x1 = x1 + e1**x1
            x2 = x2 + e2**x2
        else:
            # Simulate network condition (for example, congestion)
            print('Multiplicative D')
            x1 = x1 * 1/(e1**x1)
            x2 = x2 * 1/(e2**x2)
        # Store values in arrays
        x1_values[i] = x1
        x2_values[i] = x2
    # Display the final values
    print("Final x1:", x1)
    print("Final x2:", x2)
    
    return x1_values, x2_values

# %%
x1_values, x2_values = AI_exp()
# Out:
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Multiplicative D
# Final x1: 2.017047051347578
# Final x2: 2.017047051347578

# %%
plotAIMD_nonlinear(x1_values, x2_values, title="AIMD c^x")

# %%
def AIMD_sigm(a1=5, a2=5, b1=0.5, b2=0.5, e1=1.2, e2=1.2, iters=100):
    ITERATESMAX = iters # You can adjust this value as needed
    C = 10 # Adjust C value as needed

    x1 = 5
    x2 = 1

    x1_values = np.zeros(ITERATESMAX)
    x2_values = np.zeros(ITERATESMAX)

    for i in range(ITERATESMAX):
        if (x1 + x2 <= C):
            # Additive increase phase
            print('Additive I')
            x1 = x1 + e1**x1
            x2 = x2 + e2**x2
        else:
            # Simulate network condition (for example, congestion)
            print('Multiplicative D')
            x1 = x1 * 1/(1+e1**x1)
            x2 = x2 * 1/(1+e2**x2)
        # Store values in arrays
        x1_values[i] = x1
        x2_values[i] = x2
    # Display the final values
    print("Final x1:", x1)
    print("Final x2:", x2)
    
    return x1_values, x2_values

# %%
x1_values, x2_values = AIMD_sigm()
# Out:
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Additive I
# Additive I
# Multiplicative D
# Additive I
# Final x1: 2.8474144741009804
# Final x2: 2.8474144741009804

# %%
plotAIMD_nonlinear(x1_values, x2_values, title="AI c^x MD sigmoid")

# %% [markdown]
# ## AIMD on multiple users

# %%
def plotCwndRTT(userCwnd=[5,1,2], iter=50):
    C=20
    cwndTotal = [sum(userCwnd)]
    userCwnd_all = [userCwnd]
    print(cwndTotal)

    for i in range(iter):
        if cwndTotal[i] <= C:
            userCwnd = [x+1 for x in userCwnd]
        else:
            userCwnd = [math.floor(x/2) for x in userCwnd]
        userCwnd_all.append(userCwnd)
        cwndTotal.append(sum(userCwnd))
    
    res = [list(x) for x in zip(*userCwnd_all)]
    
    for y in res:
        x = list(range(iter+1))
        plt.plot(x, y, '-o')
        
    plt.xlabel("RTT")
    plt.ylabel("CWND")
    plt.title(f"RTT vs CWND")
    plt.show()

# %%
userCwnd = random.sample(range(1, 10), 5)
plotCwndRTT(userCwnd)
# Out:
# [25]

# %%
def plotCwndRTT(userCwnd=[5,1,2], iter=50):
    C=20
    cwndTotal = [sum(userCwnd)]
    userCwnd_all = [userCwnd]
    print(cwndTotal)

    for i in range(iter):
        if cwndTotal[i] <= C:
            userCwnd = [math.floor(x+x**0.1) for x in userCwnd]
        else:
            userCwnd = [math.floor(x/2) for x in userCwnd]
        userCwnd_all.append(userCwnd)
        cwndTotal.append(sum(userCwnd))
    
    res = [list(x) for x in zip(*userCwnd_all)]
    
    for y in res:
        x = list(range(iter+1))
        plt.plot(x, y, '-o')
        
    plt.xlabel("RTT")
    plt.ylabel("CWND")
    plt.title(f"RTT vs CWND")
    plt.show()

# %%
userCwnd = random.sample(range(1, 10), 5)
plotCwndRTT(userCwnd)
# Out:
# [19]
